# %%
# !pip install streamlit pandas requests

# %%
# !streamlit --version
# Out:
# Streamlit, version 1.12.0
# 2026-06-08 15:28:57.477 INFO    numexpr.utils: NumExpr defaulting to 4 threads.

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\DELL\\Project'
